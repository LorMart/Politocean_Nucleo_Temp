# %% [markdown]
# <a href="https://colab.research.google.com/github/LorMart/Politocean_Nucleo_Temp/blob/main/Colab_Runner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/LorMart/mldl23-ego.git
# Out:
# Cloning into 'mldl23-ego'...
# remote: Enumerating objects: 76, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 76 (delta 18), reused 19 (delta 2), pack-reused 23
# Unpacking objects: 100% (76/76), 180.11 MiB | 9.73 MiB/s, done.
# Updating files: 100% (46/46), done.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...

# %%
# !conda env create --name egovision -f mldl23-ego/requirements.yaml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ...
# testpath-0.6.0       | 85 KB     | :   0% 0/1 [00:00<?, ?it/s]
# nb_conda_kernels-2.3 | 27 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
# jupyterlab_server-2. | 75 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
# black-22.6.0         | 224 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# tornado-6.2          | 584 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# setuptools-63.4.1    | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# zipp-3.15.0          | 17 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# xz-5.2.6             | 394 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ipykernel-6.15.2     | 189 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
# %%bash
#
# cd mldl23-ego
#
# PYTHON_PATH=/usr/local/envs/egovision/bin/python
# $PYTHON_PATH train_classifier_ta3n.py name=test_ta3n_D1_D2 \
#   config=configs/ta3n.yaml \
#   dataset.shift=D1-D2 \
#   dataset.RGB.data_path=../ek_data/frames\
#   action=train
# Out:
# 1024
# Multi-Scale Temporal Relation Network Module in use ['5-frame relation', '4-frame relation', '3-frame relation', '2-frame relation']
# 512
# 512
# 512
# 512
# 1024
# torch.Size([32, 5, 1024])
# torch.Size([32, 5, 1024])
# torch.Size([32, 512])
# torch.Size([32, 512])
# torch.Size([32, 512])
# torch.Size([32, 512])
# torch.Size([32, 512])
# torch.Size([32, 512])
# torch.Size([32, 512])
# torch.Size([32, 512])
# torch.Size([32, 512])
# 2023-06-22 20:18:46 LOG INFO Running with parameters:
#   action: train
#   name: test_ta3n_D1_D2
#   modality: ['RGB']
#   total_batch: 128
#   batch_size: 32
#   gpus: None
#   wandb_name: None
#   resume_from: None
#   logname: None
#   models_dir: saved_models/test_ta3n_D1_D2/Jun22_20-18-43
#   train:
#     num_iter: 5000
#     lr_steps: 3000
#     eval_freq: 50
#     num_clips: 1
#     dense_sampling:
#       RGB: True
#     num_frames_per_clip:
#       RGB: 16
#   test:
#     num_clips: 5
#     dense_sampling:
#       RGB: True
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b40e25009dff> in <cell line: 1>()
# ----> 1 print(dict(TA3N.parameters()).keys())
#
# NameError: name 'TA3N' is not defined
